# %%
import tweepy
import json

# %% [markdown]
# ### Autenticación de usuario para la app de twitter

# %%
consumer_key = 'FsNkq2SyJl469EAnCJlzQjTbW'
consumer_secret = 'LdBzdUNzoM9dcz4Oa2BOCp8Lp6IqdvRk3khvxYRdwnWQdxnDPl'
access_token ='1339939296611069957-g6C97ncUsHoBAj5y8mH6XOegM90jv5' 
access_token_secret = 'J9hkEtJaNC1Doxe2PhE6ymT2l83x77zFUjRAkwrW0jiWk'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)

auth.set_access_token(access_token,access_token_secret)
#OBTENER MI INFORMACION
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# ### Creación de un array con los candidatos a precidencia de la república del Ecuador
# #### Estos son los nombres que usan los candidatos en la red social Twitter

# %%
candidatos = ['LassoGuillermo','AbAlvaroNoboa', 'ecuarauz' , 'yakuperezg','juanfervelasco'  ]
candidatos
# Out:
# ['LassoGuillermo', 'AbAlvaroNoboa', 'ecuarauz', 'yakuperezg', 'juanfervelasco']

# %% [markdown]
# ### Obtenemos la información relevantes para la regresión de la cuenta del candidato

# %%
for candidato in candidatos:
    data = api.get_user(candidato)
    print()
    print('DATOS DEL CANDIDATO: '+ data._json['name'])
    print('usuario  => ' +data._json['screen_name'])
    print('Ubicación => '+data._json['location'])
    print('Seguidores en Twitter => '+ str(data._json['followers_count']))
    #print(type(data._json['entities']))
    #print(type(data._json['status']))
    diccionario =data._json['entities'] 
    lista=[]
   
    for link in diccionario :  #recorremos 
        valor = diccionario[link]
        for vrd_valor in valor:
            lista = [lista,valor[vrd_valor]]
            
    new_lista = lista[0]
    listaA=new_lista[1]
    i=0;
    link_candidato=''
    for dia in listaA:
        link =dia
        for links in link:
            i=i+1
            if i == 2:
                link_candidato =link[links]
                
            #print(link[links])

    print(link_candidato)
    #print(n_list[0])
    #print(type(listaA))
    #print(data._json['status'])
    #print(data._json['expanded_url'])
    #print(json.dumps(data._json, indent=2))
# Out:
# DATOS DEL CANDIDATO: Guillermo Lasso
# usuario  => LassoGuillermo
# Ubicación =>
# Seguidores en Twitter => 624124
# http://www.guillermolasso.ec
#
# DATOS DEL CANDIDATO: Alvaro Noboa
# usuario  => AbAlvaroNoboa
# Ubicación => Guayaquil, Ecuador
# Seguidores en Twitter => 18616
# http://www.alvaronoboa.com/
#
# DATOS DEL CANDIDATO: Andrés Arauz
# usuario  => ecuarauz
# Ubicación => Ecuador
# Seguidores en Twitter => 55641
# http://facebook.com/ecuarauz2021
#
# DATOS DEL CANDIDATO: Yaku Pérez Guartambel
# usuario  => yakuperezg
# Ubicación => Cuenca de Guapondelig
# Seguidores en Twitter => 57101
# http://www.yakuperez.com
#
# DATOS DEL CANDIDATO: Juan Fernando Velasco
# usuario  => juanfervelasco
# Ubicación => Ecuador
# Seguidores en Twitter => 913194
# http://www.juanfernandovelasco.com

# %%
for tweet in tweepy.Cursor(api.user_timeline, screen_name='AbAlvaroNoboa', tweet_mode = 'extend').items(25):
    #print(json.dumps(tweet._json, indent=2))
    print('DESCRICPCIÓN TWEET:' )
    print('ID tweet  => ' +str(tweet._json['id_str']))
    print('TEXTO  => ' +str(tweet._json['text']))
    print('RETWITEADO  => ' +str(tweet._json['retweet_count']) + ' veces')
    print("LIKE's => " +str(tweet._json['favorite_count']) )
    #print('Lugar  => ' +str(tweet._json['entities']))
    #print(tweet._json['entities'])
    diccionario =tweet._json['entities'] 
    hashtags = diccionario['hashtags']
    menciones = diccionario['user_mentions']
    i=0;
    j=0;
    print('HASHTAGS:')
    for dia in hashtags:
        hst = dia
        for links in hst:
            
            i=i+1
            if i == 1:
                hastags =hst[links]
                print(hastags)
                
    print('USERS MECIONADOS:')
    for m in menciones:
        mnc = m
       #print(mnc)
        for m_user in mnc:
            j=j+1
            if j == 1:
                print(mnc[m_user])
            
    
    print('-*******************************************************')
# Out:
# DESCRICPCIÓN TWEET:
# ID tweet  => 1338659011156119553
# TEXTO  => Álvaro Noboa al país.
#
# https://t.co/Kp2vVHOvVV
# RETWITEADO  => 243 veces
# LIKE's => 437
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1337711203410440192
# TEXTO  => Con Dios. Ecuatorianos
# Nuestra prioridad es darle empleo, alimentos y salud al 100% de los ecuatorianos, eso es lo… https://t.co/lTUK75VvJf
# RETWITEADO  => 362 veces
# LIKE's => 1801
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1337603681559175168
# TEXTO  => Gracias a todos los ecuatorianos que están vigilantes a las afuera del #CNE, en sus hogares y en todas las provinci… https://t.co/UxZafzh2nE
# RETWITEADO  => 255 veces
# LIKE's => 752
# HASHTAGS:
# HASHTAGS: #CNE
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1337435194668814339
# TEXTO  => ¡GRACIAS A LA UNIÓN EUROPEA! 🇪🇺
#
# Por el respaldo y apoyo al #Ecuador durante estos difíciles momentos que atravies… https://t.co/2NzB8IpNTq
# RETWITEADO  => 230 veces
# LIKE's => 590
# HASHTAGS:
# HASHTAGS: #Ecuador
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1336858908997115910
# TEXTO  => El Comité de Derechos Humanos de las Naciones Unidas abre el caso contra Ecuador por violación de derechos político… https://t.co/ssYG5WrOY5
# RETWITEADO  => 228 veces
# LIKE's => 492
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1336812375777882117
# TEXTO  => Informe al país sobre las encuestas de Radio Sucre del 09 de Diciembre 2020 https://t.co/WPUj6hK9wr
# RETWITEADO  => 240 veces
# LIKE's => 630
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1335593224262606848
# TEXTO  => Desde el fondo de nuestros corazones💙❤️💙 junto a mi esposa, hijos y nietos les deseamos salud, progreso y prosperid… https://t.co/VRZoYyriM3
# RETWITEADO  => 264 veces
# LIKE's => 735
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1335569155765002240
# TEXTO  => Que hice durante los 10 años del Correísmo? Me quede en Ecuador generando trabajo y pagando impuestos como el más g… https://t.co/eao2J0ZLSL
# RETWITEADO  => 444 veces
# LIKE's => 3501
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1335279727175757828
# TEXTO  => Con Dios, señores del CNE, señor Guillermo Lasso del Partido 21, señores del Partido Social Cristiano, los únicos q… https://t.co/XHEFRfEVXz
# RETWITEADO  => 282 veces
# LIKE's => 715
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1335032152346464257
# TEXTO  => “Mis queridos ecuatorianos, me he tomado las redes de mi esposo para darles este mensaje”.
# Anabella❤️ https://t.co/MLFgxZwYD4
# RETWITEADO  => 722 veces
# LIKE's => 1886
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1334552088328753154
# TEXTO  => Ecuatorianos, con Dios.
# Escucha mi plan para generar trabajo para todos en el país.
# Gracias ecuatorianos, gracias D… https://t.co/EpzKRiRSVt
# RETWITEADO  => 368 veces
# LIKE's => 821
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1334169140957999105
# TEXTO  => Ecuatorianos, con Dios.
# Las elecciones del 07 de febrero del 2021, serán declaradas nulas por la mayoría de los ecu… https://t.co/Wfl7qACSJg
# RETWITEADO  => 581 veces
# LIKE's => 811
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333924694714703872
# TEXTO  => Ecuatorianos; con Dios, quiero dejar aclarado, que yo sí he aceptado el pedido de los ecuatorianos de correr para p… https://t.co/ldvxTFeqec
# RETWITEADO  => 480 veces
# LIKE's => 721
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333885734344863748
# TEXTO  => Con Dios. Ecuatorianos,
# La Cruzada Nueva Humanidad continuará dando atención médica gratuita y medicina gratuita en… https://t.co/Bb9GRxJp4C
# RETWITEADO  => 426 veces
# LIKE's => 529
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333799581612576768
# TEXTO  => ... pero que ya no hay tiempo para poder registrarme como candidato, sería un robo, no solo a mí, sino a más del 52… https://t.co/SEUu52I7Qh
# RETWITEADO  => 439 veces
# LIKE's => 492
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333799465623322629
# TEXTO  => Por eso ecuatorianos tienen que ustedes estar conscientes de que los culpables son los corruptos y que yo voy hacer… https://t.co/NZDzZSyLfN
# RETWITEADO  => 435 veces
# LIKE's => 495
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333799374829174784
# TEXTO  => ... , viendo todos los problemas de salud, de trabajo y de alimento que hay, lo hice porque los amo y acepte correr… https://t.co/dlLmVBXYRo
# RETWITEADO  => 334 veces
# LIKE's => 372
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333799314762567680
# TEXTO  => Con Dios
# Ecuatorianos a pedido de más del 52% de la población del Ecuador, resolví correr para presidente de nuestr… https://t.co/fmIKTjSEeO
# RETWITEADO  => 501 veces
# LIKE's => 767
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1333567358565298180
# TEXTO  => ¡NO DESCANSAREMOS! Hasta hacer respetar al #Ecuador🇪🇨 del abusivo atrevimiento del @cnegobec de no permitirnos la i… https://t.co/12fNr2tMDq
# RETWITEADO  => 492 veces
# LIKE's => 833
# HASHTAGS:
# HASHTAGS: #Ecuador
# USERS MECIONADOS:
# cnegobec
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1330357437971509248
# TEXTO  => Gracias Ecuador!!! https://t.co/aKXQfR76WS
# RETWITEADO  => 373 veces
# LIKE's => 8399
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1329861853107933187
# TEXTO  => Ecuatorianos, con Dios.
# Ya estamos “hasta las marimbas timbas” que violen nuestros derechos y que le roben a los po… https://t.co/TOMv4WbhrM
# RETWITEADO  => 79 veces
# LIKE's => 533
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1326981934375964677
# TEXTO  => Por eso ecuatoriano, mantente firme, los alvaristas manténganse alvaristas , yo me mantendré en la lucha pero no no… https://t.co/kFwgLOlSYB
# RETWITEADO  => 14 veces
# LIKE's => 191
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1326981791606067200
# TEXTO  => ... para ver si de esa manera los forzan a los pobres a votar por la 6, a votar por la 21 o por otro candidato, cosa que no va a ocurrir.
# RETWITEADO  => 9 veces
# LIKE's => 77
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1326981759381221377
# TEXTO  => Ustedes los pobres ¿qué es lo que tienen? Una casa de caña, un televisor y tienen lo más valioso que puedan usar ca… https://t.co/9AeywStLa9
# RETWITEADO  => 6 veces
# LIKE's => 58
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
# DESCRICPCIÓN TWEET:
# ID tweet  => 1326981626363056131
# TEXTO  => De esto se da cuenta el señor Arauz y el señor Yaku y se han mantenido calladitos de ver el error tan gigante que h… https://t.co/hvk3ajzxj7
# RETWITEADO  => 2 veces
# LIKE's => 17
# HASHTAGS:
# USERS MECIONADOS:
# -*******************************************************
